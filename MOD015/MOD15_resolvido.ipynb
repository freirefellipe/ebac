# %% [markdown]
# <a href="https://colab.research.google.com/github/freirefellipe/ebac/blob/main/MOD15_resolvido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Preços *outliers* dos diamantes:

# %%
import seaborn

diamonds_ds = seaborn.load_dataset('diamonds')

with seaborn.axes_style('whitegrid'):

  diamonds_graph = seaborn.boxplot(x=diamonds_ds['price'])

  diamonds_graph.set(title='Preços dos diamantes', xlabel='Preço (USD)')

# %% [markdown]
# **Insight**: Percebe-se, então, que a mediana de preços é de aproximadamente US 2500; com *positive skew* (ou seja, viés positivo, de maior incidência de preços acima da mediana); e que os *outliers* (valores atípicos) começam a partir do valor US 12500,0.

# %%
display(diamonds_ds['price'])
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# # 2. Correlação preço por peso de cada tipo de transparência:

# %%
import seaborn

diamonds_ds = seaborn.load_dataset('diamonds')[['price', 'carat', 'clarity']].groupby('clarity').agg('mean')

with seaborn.axes_style('whitegrid'):

  diamonds_grapho = seaborn.scatterplot(data=diamonds_ds, x='price', y='carat', hue='clarity')

  diamonds_grapho.set(title='Correlação preço por peso dos tipos de transparência.', xlabel='Preço', ylabel='Peso')

  diamonds_grapho.get_legend().set_title('Transparência')

# %% [markdown]
# **Insight**: A partir deste gráfico depreende-se que o preço do diamante aumenta de acordo com o peso, com exceção de *IF* e *VVS1*, que são iguais, eos pontos fora da curva *SI2* e *I1*: esse tendo preço na margem dos outros diamantes mesmo sendo bem mais pesado, e aquele sendo bem mais caro mesmo tendo o peso menor que *I1*.

# %%
display(diamonds_ds)
# Out:
#                price     carat
# clarity
# IF       2864.839106  0.505123
# VVS1     2523.114637  0.503321
# VVS2     3283.737071  0.596202
# VS1      3839.455391  0.727158
# VS2      3924.989395  0.763935
# SI1      3996.001148  0.850482
# SI2      5063.028606  1.077648
# I1       3924.168691  1.283846

# %% [markdown]
# # 3. Distribuição contínua aproximada do peso dos carros:

# %% [markdown]
# 3-1. Tipos de carro:

# %%
import seaborn

mpg_ds = seaborn.load_dataset('mpg')

with seaborn.axes_style('whitegrid'):

  mpg_grapho = seaborn.histplot(data=mpg_ds, x='weight', hue=len(mpg_ds['name']), palette='dark', kde=True)

  mpg_grapho.set(title='Distribuição contínua de peso dos carros em seus diversos tipos', xlabel='Peso', ylabel='Carros')

# %% [markdown]
# **Insight**: Infere-se do gráfico acima que o peso dos 398 carros em seus tipos mais variados teve aumento considerável em certo momento, apresentando em seguida queda abrupta O próximo gráfico (peso ao longo dos anos) complementa este.

# %% [markdown]
# 3-2. Ao longo dos anos:

# %%
import seaborn

mpg_ds = seaborn.load_dataset('mpg')

with seaborn.axes_style('whitegrid'):

  mpg_grapho = seaborn.histplot(data=mpg_ds, x='weight', hue=mpg_ds['model_year'])

  mpg_grapho.set(title='Distribuição contínua de peso dos carros ao longo dos anos', xlabel='Peso', ylabel='Anos')

# %% [markdown]
# **Insight**: Infere-se a partir do gráfico que o peso dos carros ao longo dos anos teve grande variação, sendo os anos de 82 e 83 os anos em que os carros eram mais pesados.

# %%
display(mpg_ds)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...
